# %%
import re

chunkdict = {}
founddict = {}


def getchunks(fname):
    f = open(fname)
    global chunkdict
    curcit = ''
    curbook = ''
    curchap = ''
    
    
    for l in f:
        
        m = re.search('(<div[^>]+subtype="([^"]+)"[^>]*)',l)
        if(m):
            cursubtype = m[2]
            curdiv = m[1]
            n = re.search('n="([^"]+)"',l)
            if(n):
                curn = n[1]
            else:
                print('no n!',curdiv)
            
            if(cursubtype=='book'):
                curbook = curn
            if(cursubtype=='chapter'):
                curchap = curn
            if(cursubtype=='section'):
                cursection = curn
                if(not curbook or not curchap):
                    print('sect',curbook,curchap,cursection)
                curcit = curbook + '.' + curchap +'.'+ cursection
                chunkdict[curcit] = 0
                #print(curcit)
            
    
        
        l = re.sub('<[^>]+>',' ',l)
        l = re.sub('\s+$','',l)
    
        if(not l):
            continue
        if(not curcit):
            continue
        
        chunkdict[curcit] = chunkdict[curcit] + len(l.split())
    f.close()
    
    
    
fname = 'tlg0003.tlg001.perseus-grc2.xml'

getchunks(fname)


fname = 'thuc.valla1564norm_lat.xml'

f = open(fname)

for foo in chunkdict:
    founddict[foo] = 0

for l in f:
    refs = re.findall('<ref n="([0-9]+\.[0-9]+\.[0-9]+)',l)
    
    for foo in refs:
        if(not foo in founddict):
            founddict[foo] = 0
        founddict[foo] = founddict[foo] + 1


f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-e75c46271307> in <module>
#      68
#      69     for foo in refs:
# ---> 70         founddict[foo] = founddict[foo] + 1
#      71
#      72
#
# KeyError: '1.11.3'

# %%
founddict
# Out:
# {'1.1.1': 0,
#  '1.1.2': 0,
#  '1.1.3': 0,
#  '1.2.1': 0,
#  '1.2.2': 0,
#  '1.2.3': 0,
#  '1.2.4': 0,
#  '1.2.5': 0,
#  '1.2.6': 0,
#  '1.3.1': 0,
#  '1.3.2': 0,
#  '1.3.3': 0,
#  '1.3.4': 0,
#  '1.4.1': 0,
#  '1.5.1': 0,
#  '1.5.2': 0,
#  '1.5.3': 0,
#  '1.6.1': 0,
#  '1.6.2': 0,
#  '1.6.3': 0,
#  '1.6.4': 0,
#  '1.6.5': 0,
#  '1.6.6': 0,
#  '1.7.1': 0,
#  '1.8.1': 0,
#  '1.8.2': 0,
#  '1.8.3': 0,
#  '1.8.4': 0,
#  '1.9.1': 0,
#  '1.9.2': 0,
#  '1.9.3': 0,
#  '1.9.4': 0,
#  '1.10.1': 0,
#  '1.10.2': 0,
#  '1.10.3': 0,
#  '1.10.4': 0,
#  '1.10.5': 0,
#  '1.11.1': 0,
#  '1.11.2': 0,
#  '1.12.1': 0,
#  '1.12.2': 0,
#  '1.12.3': 0,
#  '1.12.4': 0,
#  '1.13.1': 0,
#  '1.13.2': 0,
#  '1.13.3': 0,
#  '1.13.4': 0,
#  '1.13.5': 0,
#  '1.13.6': 0,
#  '1.14.1': 0,
#  '1.14.2': 0,
#  '1.14.3': 0,
#  '1.15.1': 0,
#  '1.15.2': 0,
#  '1.15.3': 0,
#  '1.16.1': 0,
#  '1.17.1': 0,
#  '1.18.1': 0,
#  '1.18.2': 0,
#  '1.18.3': 0,
#  '1.19.1': 0,
#  '1.20.1': 0,
#  '1.20.2': 0,
#  '1.20.3': 0,
#  '1.21.1': 0,
#  '1.21.2': 0,
#  '1.22.1': 0,
#  '1.22.2': 0,
#  '1.22.3': 0,
#  '1.22.4': 0,
#  '1.23.1': 0,
#  '1.23.2': 0,
#  '1.23.3': 0,
#  '1.23.4': 0,
#  '1.23.5': 0,
#  '1.23.6': 0,
#  '1.24.1': 0,
#  '1.24.2': 0,
#  '1.24.3': 0,
#  '1.24.4': 0,
#  '1.24.5': 0,
#  '1.24.6': 0,
#  '1.24.7': 0,
#  '1.25.1': 0,
#  '1.25.2': 0,
#  '1.25.3': 0,
#  '1.25.4': 0,
#  '1.26.1': 0,
#  '1.26.2': 0,
#  '1.26.3': 0,
#  '1.26.4': 0,
#  '1.26.5': 0,
#  '1.27.1': 0,
#  '1.27.2': 0,
#  '1.28.1': 0,
#  '1.28.2': 0,
#  '1.28.3': 0,
#  '1.28.4': 0,
#  '1.28.5': 0,
#  '1.29.1': 0,
#  '1.29.2': 0,
#  '1.29.3': 0,
#  '1.29.4': 0,
#  '1.29.5': 0,
#  '1.30.1': 0,
#  '1.30.2': 0,
#  '1.30.3': 0,
#  '1.30.4': 0,
#  '1.31.1': 0,
#  '1.31.2': 0,
#  '1.31.3': 0,
#  '1.31.4': 0,
#  '1.32.1': 0,
#  '1.32.2': 0,
#  '1.32.3': 0,
#  '1.32.4': 0,
#  '1.32.5': 0,
#  '1.33.1': 0,
#  '1.33.2': 0,
#  '1.33.3': 0,
#  '1.33.4': 0,
#  '1.34.1': 0,
#  '1.34.2': 0,
#  '1.34.3': 0,
#  '1.35.1': 0,
#  '1.35.2': 0,
#  '1.35.3': 0,
#  '1.35.4': 0,
#  '1.35.5': 0,
#  '1.36.1': 0,
#  '1.36.2': 0,
#  '1.36.3': 0,
#  '1.36.4': 0,
#  '1.37.1': 0,
#  '1.37.2': 0,
#  '1.37.3': 0,
#  '1.37.4': 0,
#  '1.37.5': 0,
#  '1.38.1': 0,
#  '1.38.2': 0,
#  '1.38.3': 0,
#  '1.38.4': 0,
#  '1.38.5': 0,
#  '1.39.1': 0,
#  '1.39.2': 0,
#  '1.39.3': 0,
#  '1.40.1': 0,
#  '1.40.2': 0,
#  '1.40.3': 0,
#  '1.40.4': 0,
#  '1.40.5': 0,
#  '1.40.6': 0,
#  '1.41.1': 0,
#  '1.41.2': 0,
#  '1.41.3': 0,
#  '1.42.1': 0,
#  '1.42.2': 0,
#  '1.42.3': 0,
#  '1.42.4': 0,
#  '1.43.1': 0,
#  '1.43.2': 0,
#  '1.43.3': 0,
#  '1.43.4': 0,
#  '1.44.1': 0,
#  '1.44.2': 0,
#  '1.44.3': 0,
#  '1.45.1': 0,
#  '1.45.2': 0,
#  '1.45.3': 0,
#  '1.46.1': 0,
#  '1.46.2': 0,
#  '1.46.3': 0,
#  '1.46.4': 0,
#  '1.46.5': 0,
#  '1.47.1': 0,
#  '1.47.2': 0,
#  '1.47.3': 0,
#  '1.48.1': 0,
#  '1.48.2': 0,
#  '1.48.3': 0,
#  '1.48.4': 0,
#  '1.49.1': 0,
#  '1.49.2': 0,
#  '1.49.3': 0,
#  '1.49.4': 0,
#  '1.49.5': 0,
#  '1.49.6': 0,
#  '1.49.7': 0,
#  '1.50.1': 0,
#  '1.50.2': 0,
#  '1.50.3': 0,
#  '1.50.4': 0,
#  '1.50.5': 0,
#  '1.51.1': 0,
#  '1.51.2': 0,
#  '1.51.3': 0,
#  '1.51.4': 0,
#  '1.51.5': 0,
#  '1.52.1': 0,
#  '1.52.2': 0,
#  '1.52.3': 0,
#  '1.53.1': 0,
#  '1.53.2': 0,
#  '1.53.3': 0,
#  '1.53.4': 0,
#  '1.54.1': 0,
#  '1.54.2': 0,
#  '1.55.1': 0,
#  '1.55.2': 0,
#  '1.56.1': 0,
#  '1.56.2': 0,
#  '1.57.1': 0,
#  '1.57.2': 0,
#  '1.57.3': 0,
#  '1.57.4': 0,
#  '1.57.5': 0,
#  '1.57.6': 0,
#  '1.58.1': 0,
#  '1.58.2': 0,
#  '1.59.1': 0,
#  '1.59.2': 0,
#  '1.60.1': 0,
#  '1.60.2': 0,
#  '1.60.3': 0,
#  '1.61.1': 0,
#  '1.61.2': 0,
#  '1.61.3': 0,
#  '1.61.4': 0,
#  '1.61.5': 0,
#  '1.62.1': 0,
#  '1.62.2': 0,
#  '1.62.3': 0,
#  '1.62.4': 0,
#  '1.62.5': 0,
#  '1.62.6': 0,
#  '1.63.1': 0,
#  '1.63.2': 0,
#  '1.63.3': 0,
#  '1.64.1': 0,
#  '1.64.2': 0,
#  '1.64.3': 0,
#  '1.65.1': 0,
#  '1.65.2': 0,
#  '1.66.1': 0,
#  '1.67.1': 0,
#  '1.67.2': 0,
#  '1.67.3': 0,
#  '1.67.4': 0,
#  '1.67.5': 0,
#  '1.68.1': 0,
#  '1.68.2': 0,
#  '1.68.3': 0,
#  '1.68.4': 0,
#  '1.69.1': 0,
#  '1.69.2': 0,
#  '1.69.3': 0,
#  '1.69.4': 0,
#  '1.69.5': 0,
#  '1.69.6': 0,
#  '1.70.1': 0,
#  '1.70.2': 0,
#  '1.70.3': 0,
#  '1.70.4': 0,
#  '1.70.5': 0,
#  '1.70.6': 0,
#  '1.70.7': 0,
#  '1.70.8': 0,
#  '1.70.9': 0,
#  '1.71.1': 0,
#  '1.71.2': 0,
#  '1.71.3': 0,
#  '1.71.4': 0,
#  '1.71.5': 0,
#  '1.71.6': 0,
#  '1.71.7': 0,
#  '1.72.1': 0,
#  '1.72.2': 0,
#  '1.73.1': 0,
#  '1.73.2': 0,
#  '1.73.3': 0,
#  '1.73.4': 0,
#  '1.73.5': 0,
#  '1.74.1': 0,
#  '1.74.2': 0,
#  '1.74.3': 0,
#  '1.74.4': 0,
#  '1.75.1': 0,
#  '1.75.2': 0,
#  '1.75.3': 0,
#  '1.75.4': 0,
#  '1.75.5': 0,
#  '1.76.1': 0,
#  '1.76.2': 0,
#  '1.76.3': 0,
#  '1.76.4': 0,
#  '1.77.1': 0,
#  '1.77.2': 0,
#  '1.77.3': 0,
#  '1.77.4': 0,
#  '1.77.5': 0,
#  '1.77.6': 0,
#  '1.78.1': 0,
#  '1.78.2': 0,
#  '1.78.3': 0,
#  '1.78.4': 0,
#  '1.79.1': 0,
#  '1.79.2': 0,
#  '1.80.1': 0,
#  '1.80.2': 0,
#  '1.80.3': 0,
#  '1.80.4': 0,
#  '1.81.1': 0,
#  '1.81.2': 0,
#  '1.81.3': 0,
#  '1.81.4': 0,
#  '1.81.5': 0,
#  '1.81.6': 0,
#  '1.82.1': 0,
#  '1.82.2': 0,
#  '1.82.3': 0,
#  '1.82.4': 0,
#  '1.82.5': 0,
#  '1.82.6': 0,
#  '1.83.1': 0,
#  '1.83.2': 0,
#  '1.83.3': 0,
#  '1.84.1': 0,
#  '1.84.2': 0,
#  '1.84.3': 0,
#  '1.84.4': 0,
#  '1.85.1': 0,
#  '1.85.2': 0,
#  '1.85.3': 0,
#  '1.86.1': 0,
#  '1.86.2': 0,
#  '1.86.3': 0,
#  '1.86.4': 0,
#  '1.86.5': 0,
#  '1.87.1': 0,
#  '1.87.2': 0,
#  '1.87.3': 0,
#  '1.87.4': 0,
#  '1.87.5': 0,
#  '1.87.6': 0,
#  '1.88.1': 0,
#  '1.89.1': 0,
#  '1.89.2': 0,
#  '1.89.3': 0,
#  '1.90.1': 0,
#  '1.90.2': 0,
#  '1.90.3': 0,
#  '1.90.4': 0,
#  '1.90.5': 0,
#  '1.91.1': 0,
#  '1.91.2': 0,
#  '1.91.3': 0,
#  '1.91.4': 0,
#  '1.91.5': 0,
#  '1.91.6': 0,
#  '1.91.7': 0,
#  '1.92.1': 0,
#  '1.93.1': 0,
#  '1.93.2': 0,
#  '1.93.3': 0,
#  '1.93.4': 0,
#  '1.93.5': 0,
#  '1.93.6': 0,
#  '1.93.7': 0,
#  '1.93.8': 0,
#  '1.94.1': 0,
#  '1.94.2': 0,
#  '1.95.1': 0,
#  '1.95.2': 0,
#  '1.95.3': 0,
#  '1.95.4': 0,
#  '1.95.5': 0,
#  '1.95.6': 0,
#  '1.95.7': 0,
#  '1.96.1': 0,
#  '1.96.2': 0,
#  '1.97.1': 0,
#  '1.97.2': 0,
#  '1.98.1': 0,
#  '1.98.2': 0,
#  '1.98.3': 0,
#  '1.98.4': 0,
#  '1.99.1': 0,
#  '1.99.2': 0,
#  '1.99.3': 0,
#  '1.100.1': 0,
#  '1.100.2': 0,
#  '1.100.3': 0,
#  '1.101.1': 0,
#  '1.101.2': 0,
#  '1.101.3': 0,
#  '1.102.1': 0,
#  '1.102.2': 0,
#  '1.102.3': 0,
#  '1.102.4': 0,
#  '1.103.1': 0,
#  '1.103.2': 0,
#  '1.103.3': 0,
#  '1.103.4': 0,
#  '1.104.1': 0,
#  '1.104.2': 0,
#  '1.105.1': 0,
#  '1.105.2': 0,
#  '1.105.3': 0,
#  '1.105.4': 0,
#  '1.105.5': 0,
#  '1.105.6': 0,
#  '1.106.1': 0,
#  '1.106.2': 0,
#  '1.107.1': 0,
#  '1.107.2': 0,
#  '1.107.3': 0,
#  '1.107.4': 0,
#  '1.107.5': 0,
#  '1.107.6': 0,
#  '1.107.7': 0,
#  '1.108.1': 0,
#  '1.108.2': 0,
#  '1.108.3': 0,
#  '1.108.4': 0,
#  '1.108.5': 0,
#  '1.109.1': 0,
#  '1.109.2': 0,
#  '1.109.3': 0,
#  '1.109.4': 0,
#  '1.110.1': 0,
#  '1.110.2': 0,
#  '1.110.3': 0,
#  '1.110.4': 0,
#  '1.111.1': 0,
#  '1.111.2': 0,
#  '1.111.3': 0,
#  '1.112.1': 0,
#  '1.112.2': 0,
#  '1.112.3': 0,
#  '1.112.4': 0,
#  '1.112.5': 0,
#  '1.113.1': 0,
#  '1.113.2': 0,
#  '1.113.3': 0,
#  '1.113.4': 0,
#  '1.114.1': 0,
#  '1.114.2': 0,
#  '1.114.3': 0,
#  '1.115.1': 0,
#  '1.115.2': 0,
#  '1.115.3': 0,
#  '1.115.4': 0,
#  '1.115.5': 0,
#  '1.116.1': 0,
#  '1.116.2': 0,
#  '1.116.3': 0,
#  '1.117.1': 0,
#  '1.117.2': 0,
#  '1.117.3': 0,
#  '1.118.1': 0,
#  '1.118.2': 0,
#  '1.118.3': 0,
#  '1.119.1': 0,
#  '1.120.1': 0,
#  '1.120.2': 0,
#  '1.120.3': 0,
#  '1.120.4': 0,
#  '1.120.5': 0,
#  '1.121.1': 0,
#  '1.121.2': 0,
#  '1.121.3': 0,
#  '1.121.4': 0,
#  '1.121.5': 0,
#  '1.122.1': 0,
#  '1.122.2': 0,
#  '1.122.3': 0,
#  '1.122.4': 0,
#  '1.123.1': 0,
#  '1.123.2': 0,
#  '1.124.1': 0,
#  '1.124.2': 0,
#  '1.124.3': 0,
#  '1.125.1': 0,
#  '1.125.2': 0,
#  '1.126.1': 0,
#  '1.126.2': 0,
#  '1.126.3': 0,
#  '1.126.4': 0,
#  '1.126.5': 0,
#  '1.126.6': 0,
#  '1.126.7': 0,
#  '1.126.8': 0,
#  '1.126.9': 0,
#  '1.126.10': 0,
#  '1.126.11': 0,
#  '1.126.12': 0,
#  '1.127.1': 0,
#  '1.127.2': 0,
#  '1.127.3': 0,
#  '1.128.1': 0,
#  '1.128.2': 0,
#  '1.128.3': 0,
#  '1.128.4': 0,
#  '1.128.5': 0,
#  '1.128.6': 0,
#  '1.128.7': 0,
#  '1.129.1': 0,
#  '1.129.2': 0,
#  '1.129.3': 0,
#  '1.130.1': 0,
#  '1.130.2': 0,
#  '1.131.1': 0,
#  '1.131.2': 0,
#  '1.132.1': 0,
#  '1.132.2': 0,
#  '1.132.3': 0,
#  '1.132.4': 0,
#  '1.132.5': 0,
#  '1.133.1': 0,
#  '1.134.1': 0,
#  '1.134.2': 0,
#  '1.134.3': 0,
#  '1.134.4': 0,
#  '1.135.1': 0,
#  '1.135.2': 0,
#  '1.135.3': 0,
#  '1.136.1': 0,
#  '1.136.2': 0,
#  '1.136.3': 0,
#  '1.136.4': 0,
#  '1.137.1': 0,
#  '1.137.2': 0,
#  '1.137.3': 0,
#  '1.137.4': 0,
#  '1.138.1': 0,
#  '1.138.2': 0,
#  '1.138.3': 0,
#  '1.138.4': 0,
#  '1.138.5': 0,
#  '1.138.6': 0,
#  '1.139.1': 0,
#  '1.139.2': 0,
#  '1.139.3': 0,
#  '1.139.4': 0,
#  '1.140.1': 0,
#  '1.140.2': 0,
#  '1.140.3': 0,
#  '1.140.4': 0,
#  '1.140.5': 0,
#  '1.141.1': 0,
#  '1.141.2': 0,
#  '1.141.3': 0,
#  '1.141.4': 0,
#  '1.141.5': 0,
#  '1.141.6': 0,
#  '1.141.7': 0,
#  '1.142.1': 0,
#  '1.142.2': 0,
#  '1.142.3': 0,
#  '1.142.4': 0,
#  '1.142.5': 0,
#  '1.142.6': 0,
#  '1.142.7': 0,
#  '1.142.8': 0,
#  '1.142.9': 0,
#  '1.143.1': 0,
#  '1.143.2': 0,
#  '1.143.3': 0,
#  '1.143.4': 0,
#  '1.143.5': 0,
#  '1.144.1': 0,
#  '1.144.2': 0,
#  '1.144.3': 0,
#  '1.144.4': 0,
#  '1.145.1': 0,
#  '1.146.1': 0,
#  '2.1.1': 0,
#  '2.2.1': 0,
#  '2.2.2': 0,
#  '2.2.3': 0,
#  '2.2.4': 0,
#  '2.3.1': 0,
#  '2.3.2': 0,
#  '2.3.3': 0,
#  '2.3.4': 0,
#  '2.4.1': 0,
#  '2.4.2': 0,
#  '2.4.3': 0,
#  '2.4.4': 0,
#  '2.4.5': 0,
#  '2.4.6': 0,
#  '2.4.7': 0,
#  '2.4.8': 0,
#  '2.5.1': 0,
#  '2.5.2': 0,
#  '2.5.3': 0,
#  '2.5.4': 0,
#  '2.5.5': 0,
#  '2.5.6': 0,
#  '2.5.7': 0,
#  '2.6.1': 0,
#  '2.6.2': 0,
#  '2.6.3': 0,
#  '2.6.4': 0,
#  '2.7.1': 0,
#  '2.7.2': 0,
#  '2.7.3': 0,
#  '2.8.1': 0,
#  '2.8.2': 0,
#  '2.8.3': 0,
#  '2.8.4': 0,
#  '2.8.5': 0,
#  '2.9.1': 0,
#  '2.9.2': 0,
#  '2.9.3': 0,
#  '2.9.4': 0,
#  '2.9.5': 0,
#  '2.9.6': 0,
#  '2.10.1': 0,
#  '2.10.2': 0,
#  '2.10.3': 0,
#  '2.11.1': 0,
#  '2.11.2': 0,
#  '2.11.3': 0,
#  '2.11.4': 0,
#  '2.11.5': 0,
#  '2.11.6': 0,
#  '2.11.7': 0,
#  '2.11.8': 0,
#  '2.11.9': 0,
#  '2.12.1': 0,
#  '2.12.2': 0,
#  '2.12.3': 0,
#  '2.12.4': 0,
#  '2.12.5': 0,
#  '2.13.1': 0,
#  '2.13.2': 0,
#  '2.13.3': 0,
#  '2.13.4': 0,
#  '2.13.5': 0,
#  '2.13.6': 0,
#  '2.13.7': 0,
#  '2.13.8': 0,
#  '2.13.9': 0,
#  '2.14.1': 0,
#  '2.14.2': 0,
#  '2.15.1': 0,
#  '2.15.2': 0,
#  '2.15.3': 0,
#  '2.15.4': 0,
#  '2.15.5': 0,
#  '2.15.6': 0,
#  '2.16.1': 0,
#  '2.16.2': 0,
#  '2.17.1': 0,
#  '2.17.2': 0,
#  '2.17.3': 0,
#  '2.17.4': 0,
#  '2.17.5': 0,
#  '2.18.1': 0,
#  '2.18.2': 0,
#  '2.18.3': 0,
#  '2.18.4': 0,
#  '2.18.5': 0,
#  '2.19.1': 0,
#  '2.19.2': 0,
#  '2.20.1': 0,
#  '2.20.2': 0,
#  '2.20.3': 0,
#  '2.20.4': 0,
#  '2.20.5': 0,
#  '2.21.1': 0,
#  '2.21.2': 0,
#  '2.21.3': 0,
#  '2.22.1': 0,
#  '2.22.2': 0,
#  '2.22.3': 0,
#  '2.23.1': 0,
#  '2.23.2': 0,
#  '2.23.3': 0,
#  '2.24.1': 0,
#  '2.24.2': 0,
#  '2.25.1': 0,
#  '2.25.2': 0,
#  '2.25.3': 0,
#  '2.25.4': 0,
#  '2.25.5': 0,
#  '2.26.1': 0,
#  '2.26.2': 0,
#  '2.27.1': 0,
#  '2.27.2': 0,
#  '2.28.1': 0,
#  '2.29.1': 0,
#  '2.29.2': 0,
#  '2.29.3': 0,
#  '2.29.4': 0,
#  '2.29.5': 0,
#  '2.29.6': 0,
#  '2.29.7': 0,
#  '2.30.1': 0,
#  '2.30.2': 0,
#  '2.31.1': 0,
#  '2.31.2': 0,
#  '2.31.3': 0,
#  '2.32.1': 0,
#  '2.33.1': 0,
#  '2.33.2': 0,
#  '2.33.3': 0,
#  '2.34.1': 0,
#  '2.34.2': 0,
#  '2.34.3': 0,
#  '2.34.4': 0,
#  '2.34.5': 0,
#  '2.34.6': 0,
#  '2.34.7': 0,
#  '2.34.8': 0,
#  '2.35.1': 0,
#  '2.35.2': 0,
#  '2.35.3': 0,
#  '2.36.1': 0,
#  '2.36.2': 0,
#  '2.36.3': 0,
#  '2.36.4': 0,
#  '2.37.1': 0,
#  '2.37.2': 0,
#  '2.37.3': 0,
#  '2.38.1': 0,
#  '2.38.2': 0,
#  '2.39.1': 0,
#  '2.39.2': 0,
#  '2.39.3': 0,
#  '2.39.4': 0,
#  '2.40.1': 0,
#  '2.40.2': 0,
#  '2.40.3': 0,
#  '2.40.4': 0,
#  '2.40.5': 0,
#  '2.41.1': 0,
#  '2.41.2': 0,
#  '2.41.3': 0,
#  '2.41.4': 0,
#  '2.41.5': 0,
#  '2.42.1': 0,
#  '2.42.2': 0,
#  '2.42.3': 0,
#  '2.42.4': 0,
#  '2.43.1': 0,
#  '2.43.2': 0,
#  '2.43.3': 0,
#  '2.43.4': 0,
#  '2.43.5': 0,
#  '2.43.6': 0,
#  '2.44.1': 0,
#  '2.44.2': 0,
#  '2.44.3': 0,
#  '2.44.4': 0,
#  '2.45.1': 0,
#  '2.45.2': 0,
#  '2.46.1': 0,
#  '2.46.2': 0,
#  '2.47.1': 0,
#  '2.47.2': 0,
#  '2.47.3': 0,
#  '2.47.4': 0,
#  '2.48.1': 0,
#  '2.48.2': 0,
#  '2.48.3': 0,
#  '2.49.1': 0,
#  '2.49.2': 0,
#  '2.49.3': 0,
#  '2.49.4': 0,
#  '2.49.5': 0,
#  '2.49.6': 0,
#  '2.49.7': 0,
#  '2.49.8': 0,
#  '2.50.1': 0,
#  '2.50.2': 0,
#  '2.51.1': 0,
#  '2.51.2': 0,
#  '2.51.3': 0,
#  '2.51.4': 0,
#  '2.51.5': 0,
#  '2.51.6': 0,
#  '2.52.1': 0,
#  '2.52.2': 0,
#  '2.52.3': 0,
#  '2.52.4': 0,
#  '2.53.1': 0,
#  '2.53.2': 0,
#  '2.53.3': 0,
#  '2.53.4': 0,
#  '2.54.1': 0,
#  '2.54.2': 0,
#  '2.54.3': 0,
#  '2.54.4': 0,
#  '2.54.5': 0,
#  '2.55.1': 0,
#  '2.55.2': 0,
#  '2.56.1': 0,
#  '2.56.2': 0,
#  '2.56.3': 0,
#  '2.56.4': 0,
#  '2.56.5': 0,
#  '2.56.6': 0,
#  '2.57.1': 0,
#  '2.57.2': 0,
#  '2.58.1': 0,
#  '2.58.2': 0,
#  '2.58.3': 0,
#  '2.59.1': 0,
#  '2.59.2': 0,
#  '2.59.3': 0,
#  '2.60.1': 0,
#  '2.60.2': 0,
#  '2.60.3': 0,
#  '2.60.4': 0,
#  '2.60.5': 0,
#  '2.60.6': 0,
#  '2.60.7': 0,
#  '2.61.1': 0,
#  '2.61.2': 0,
#  '2.61.3': 0,
#  '2.61.4': 0,
#  '2.62.1': 0,
#  '2.62.2': 0,
#  '2.62.3': 0,
#  '2.62.4': 0,
#  '2.62.5': 0,
#  '2.63.1': 0,
#  '2.63.2': 0,
#  '2.63.3': 0,
#  '2.64.1': 0,
#  '2.64.2': 0,
#  '2.64.3': 0,
#  '2.64.4': 0,
#  '2.64.5': 0,
#  '2.64.6': 0,
#  '2.65.1': 0,
#  '2.65.2': 0,
#  '2.65.3': 0,
#  '2.65.4': 0,
#  '2.65.5': 0,
#  '2.65.6': 0,
#  '2.65.7': 0,
#  '2.65.8': 0,
#  '2.65.9': 0,
#  '2.65.10': 0,
#  '2.65.11': 0,
#  '2.65.12': 0,
#  '2.65.13': 0,
#  '2.66.1': 0,
#  '2.66.2': 0,
#  '2.67.1': 0,
#  '2.67.2': 0,
#  '2.67.3': 0,
#  '2.67.4': 0,
#  '2.68.1': 0,
#  '2.68.2': 0,
#  '2.68.3': 0,
#  '2.68.4': 0,
#  '2.68.5': 0,
#  '2.68.6': 0,
#  '2.68.7': 0,
#  '2.68.8': 0,
#  '2.68.9': 0,
#  '2.69.1': 0,
#  '2.69.2': 0,
#  '2.70.1': 0,
#  '2.70.2': 0,
#  '2.70.3': 0,
#  '2.70.4': 0,
#  '2.71.1': 0,
#  '2.71.2': 0,
#  '2.71.3': 0,
#  '2.71.4': 0,
#  '2.72.1': 0,
#  '2.72.2': 0,
#  '2.72.3': 0,
#  '2.73.1': 0,
#  '2.73.2': 0,
#  '2.73.3': 0,
#  '2.74.1': 0,
#  '2.74.2': 0,
#  '2.75.1': 0,
#  '2.75.2': 0,
#  '2.75.3': 0,
#  '2.75.4': 0,
#  '2.75.5': 0,
#  '2.75.6': 0,
#  '2.76.1': 0,
#  '2.76.2': 0,
#  '2.76.3': 0,
#  '2.76.4': 0,
#  '2.77.1': 0,
#  '2.77.2': 0,
#  '2.77.3': 0,
#  '2.77.4': 0,
#  '2.77.5': 0,
#  '2.77.6': 0,
#  '2.78.1': 0,
#  '2.78.2': 0,
#  '2.78.3': 0,
#  '2.78.4': 0,
#  '2.79.1': 0,
#  '2.79.2': 0,
#  '2.79.3': 0,
#  '2.79.4': 0,
#  '2.79.5': 0,
#  '2.79.6': 0,
#  '2.79.7': 0,
#  '2.80.1': 0,
#  '2.80.2': 0,
#  '2.80.3': 0,
#  '2.80.4': 0,
#  '2.80.5': 0,
#  '2.80.6': 0,
#  '2.80.7': 0,
#  '2.80.8': 0,
#  '2.81.1': 0,
#  '2.81.2': 0,
#  '2.81.3': 0,
#  '2.81.4': 0,
#  '2.81.5': 0,
#  '2.81.6': 0,
#  '2.81.7': 0,
#  '2.81.8': 0,
#  '2.82.1': 0,
#  '2.83.1': 0,
#  '2.83.2': 0,
#  '2.83.3': 0,
#  '2.83.4': 0,
#  '2.83.5': 0,
#  '2.84.1': 0,
#  '2.84.2': 0,
#  '2.84.3': 0,
#  '2.84.4': 0,
#  '2.84.5': 0,
#  '2.85.1': 0,
#  '2.85.2': 0,
#  '2.85.3': 0,
#  '2.85.4': 0,
#  '2.85.5': 0,
#  '2.85.6': 0,
#  '2.86.1': 0,
#  '2.86.2': 0,
#  '2.86.3': 0,
#  '2.86.4': 0,
#  '2.86.5': 0,
#  '2.86.6': 0,
#  '2.87.1': 0,
#  '2.87.2': 0,
#  '2.87.3': 0,
#  '2.87.4': 0,
#  '2.87.5': 0,
#  '2.87.6': 0,
#  '2.87.7': 0,
#  '2.87.8': 0,
#  '2.87.9': 0,
#  '2.88.1': 0,
#  '2.88.2': 0,
#  '2.88.3': 0,
#  '2.89.1': 0,
#  '2.89.2': 0,
#  '2.89.3': 0,
#  '2.89.4': 0,
#  '2.89.5': 0,
#  '2.89.6': 0,
#  '2.89.7': 0,
#  '2.89.8': 0,
#  '2.89.9': 0,
#  '2.89.10': 0,
#  '2.89.11': 0,
#  '2.90.1': 0,
#  '2.90.2': 0,
#  '2.90.3': 0,
#  '2.90.4': 0,
#  '2.90.5': 0,
#  '2.90.6': 0,
#  '2.91.1': 0,
#  '2.91.2': 0,
#  '2.91.3': 0,
#  '2.91.4': 0,
#  '2.92.1': 0,
#  '2.92.2': 0,
#  '2.92.3': 0,
#  '2.92.4': 0,
#  '2.92.5': 0,
#  '2.92.6': 0,
#  '2.92.7': 0,
#  '2.93.1': 0,
#  '2.93.2': 0,
#  '2.93.3': 0,
#  '2.93.4': 0,
#  '2.94.1': 0,
#  '2.94.2': 0,
#  '2.94.3': 0,
#  '2.94.4': 0,
#  '2.95.1': 0,
#  '2.95.2': 0,
#  '2.95.3': 0,
#  ...}
